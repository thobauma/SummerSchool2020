# %% [markdown]
# ## Exercise 8
#
# 1. Apply a non-linear dimensionality reduction technique, such as UMAP and plot the corresponding embedding

# %%
import sklearn
from sklearn.datasets import fetch_openml

X, y = fetch_openml('mnist_784', version=1, return_X_y=True) 
X /= 255.0 # scale to 0-1 range
y = sklearn.preprocessing.LabelEncoder().fit_transform(y)

# %%
import cuml
from cuml import PCA, UMAP, TSNE 
import numpy as np
import matplotlib.pyplot as plt

# %%
pca = PCA(n_components=2)
pca.fit(X)
v = pca.transform(X)

# %%
plt.figure(figsize=(16,10))
plt.plot(v[:,0], v[:,1], '.', ms=3)

# %%
plt.figure(figsize=(16,10))
for it in range(10):
    idx=(y==it)
    plt.plot(v[idx,0], v[idx,1], '.', ms=3, label='{}'.format(it))
plt.legend(markerscale=10, fontsize=16)

# %%
umap = UMAP(n_components=2, n_epochs=200)
umap.fit(X)
u = umap.transform(X)

# %%
plt.figure(figsize=(16,10))
plt.plot(u[:,0], u[:,1], '.', ms=3)

# %%
plt.figure(figsize=(16,10))
for it in range(10):
    idx=(y==it)
    plt.plot(u[idx,0], u[idx,1], '.', ms=3, label='{}'.format(it))
plt.legend(markerscale=10, fontsize=16)

# %%
umap = UMAP(n_neighbors=2,n_components=2, n_epochs=300)
umap.fit(X)
u = umap.transform(X)
plt.figure(figsize=(16,10))
for it in range(10):
    idx=(y==it)
    plt.plot(u[idx,0], u[idx,1], '.', ms=3, label='{}'.format(it))
plt.legend(markerscale=10, fontsize=16)

# %%
umap = UMAP(n_neighbors=100,n_components=2, n_epochs=300)
umap.fit(X)
u = umap.transform(X)
plt.figure(figsize=(16,10))
for it in range(10):
    idx=(y==it)
    plt.plot(u[idx,0], u[idx,1], '.', ms=3, label='{}'.format(it))
plt.legend(markerscale=10, fontsize=16)
